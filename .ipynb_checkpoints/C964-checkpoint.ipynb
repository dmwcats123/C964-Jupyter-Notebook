# %% [markdown]
# <h1>C964 Capstone Project</h1>

# %%
import pandas as pd
import numpy as np
import ipywidgets as widget
import os
import glob
import matplotlib as mp
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dropout

# %%
path = os.getcwd()
csvfiles = glob.glob(os.path.join(path, "data/*.csv"))

df = None
def dropdownFunc(Stock):
    for file in csvfiles:
        if Stock in file:
            return file

dropdown = widget.interactive(dropdownFunc, Stock=['AAPL', 'AMD', 'AMZN', 'ATVI', 'BABA', 'BAC', 'CRM', 'CSCO', 'DIS', 'EA', 'F', 'GOOG', 'INTC', 'JPM', 'KO', 'MCD', 'META', 'MSFT', 'MTCH', 'NFLX', 'NVDA', 'PFE', 'PYPL', 'T', 'TSLA','TTD','WMT','XOM','YELP','ZG'])
display(dropdown)
# Out:
# interactive(children=(Dropdown(description='Stock', options=('AAPL', 'AMD', 'AMZN', 'ATVI', 'BABA', 'BAC', 'CR…

# %% [markdown]
# <p style="font-size: larger">Use the combo box above to select the stock you are interested in analyzing.

# %% [markdown]
# </p>

# %%
df = pd.read_csv(dropdown.result)
df.head()
openValues = df.Open
closeValues = df.Close
dates = df.Date
plt.figure(figsize=(15,10))
plt.plot(dates, df.Open)
plt.xticks([0, 500, 1000, 1500, 2000, 2517])
plt.title("Open Prices")
plt.savefig("open_prices.jpg")
plt.show()
plt.close()

print(df)
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2013-01-02   19.779285   19.821428   19.343929   19.608213   16.862818
# 1     2013-01-03   19.567142   19.631071   19.321428   19.360714   16.649981
# 2     2013-01-04   19.177500   19.236786   18.779642   18.821428   16.186199
# 3     2013-01-07   18.642857   18.903570   18.400000   18.710714   16.090986
# 4     2013-01-08   18.900356   18.996071   18.616072   18.761070   16.134293
# ...          ...         ...         ...         ...         ...         ...
# 2513  2022-12-23  130.919998  132.419998  129.639999  131.860001  131.860001
# 2514  2022-12-27  131.380005  131.410004  128.720001  130.029999  130.029999
# 2515  2022-12-28  129.669998  131.029999  125.870003  126.040001  126.040001
# 2516  2022-12-29  127.989998  130.479996  127.730003  129.610001  129.610001
# 2517  2022-12-30  128.410004  129.949997  127.430000  129.929993  129.929993
#
#          Volume
# 0     560518000
# 1     352965200
# 2     594333600
# 3     484156400
# 4     458707200
# ...         ...
# 2513   63814900
# 2514   69007800
# 2515   85438400
# 2516   75703700
# 2517   76960600
#
# [2518 rows x 7 columns]

# %% [markdown]
# Above we simply plotted the open prices of the stock. Below we will split the data into our training data and our test data.

# %%
training_data = df[:2265]
test_data = df[2265:]

open_training = training_data.iloc[:,1:2].values
open_test = test_data.iloc[:,1:2].values

sc = MinMaxScaler(feature_range=(0,1))
training_set_scaled= sc.fit_transform(open_training)

x_train = []
y_train = []

for i in range (60,2265):
    x_train.append(training_set_scaled[i-60:i,0])
    y_train.append(training_set_scaled[i,0])
x_train = np.array(x_train)
y_train = np.array(y_train)

x_train = np.reshape(x_train,(x_train.shape[0], x_train.shape[1], 1))
print(x_train.shape)
print(y_train.shape)
# Out:
# (2205, 60, 1)
# (2205,)

# %%
regressor = Sequential()
regressor.add(LSTM(units=50, return_sequences=True, input_shape=(x_train.shape[1], 1)))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units=50, return_sequences=True))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units = 50, return_sequences=True))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.2))

regressor.add(Dense(units=1))

regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')
regressor.fit(x_train, y_train, epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
#
# Epoch 74/100
# 69/69 [==============================] - 4s 59ms/step - loss: 6.4671e-04
# Epoch 75/100
# 69/69 [==============================] - 4s 58ms/step - loss: 6.4338e-04
# Epoch 76/100
# 69/69 [==============================] - 4s 56ms/step - loss: 6.6033e-04
# Epoch 77/100
# 69/69 [==============================] - 4s 60ms/step - loss: 5.7228e-04
# Epoch 78/100
# 69/69 [==============================] - 4s 56ms/step - loss: 6.3307e-04
# Epoch 79/100
# 69/69 [==============================] - 5s 67ms/step - loss: 7.2356e-04
# Epoch 80/100
# 69/69 [==============================] - 6s 80ms/step - loss: 7.5577e-04
# Epoch 81/100
# 69/69 [==============================] - 4s 62ms/step - loss: 6.7741e-04
# Epoch 82/100
# 69/69 [==============================] - 4s 57ms/step - loss: 6.3683e-04
# Epoch 83/100
# 69/69 [==============================] - 4s 56ms/step - loss: 6.9273e-04
# Epoch 84/100
# 69/69 [==============================] - 4s 56ms/step - loss: 6.2306e-04
# Epoch 85/100
# 69/69 [==============================] - 4s 57ms/step - loss: 5.7482e-04
# Epoch 86/100
# 69/69 [==============================] - 4s 61ms/step - loss: 5.9902e-04
# Epoch 87/100
# 69/69 [==============================] - 4s 57ms/step - loss: 6.7200e-04
# Epoch 88/100
# 69/69 [==============================] - 4s 56ms/step - loss: 6.9171e-04
# Epoch 89/100
# 69/69 [==============================] - 4s 56ms/step - loss: 6.3756e-04
# Epoch 90/100
# 69/69 [==============================] - 4s 58ms/step - loss: 6.8056e-04
# Epoch 91/100
# 69/69 [==============================] - 4s 56ms/step - loss: 5.5313e-04
# Epoch 92/100
# 69/69 [==============================] - 4s 56ms/step - loss: 6.7681e-04
# Epoch 93/100
# 69/69 [==============================] - 4s 56ms/step - loss: 5.8080e-04
# Epoch 94/100
# 69/69 [==============================] - 4s 59ms/step - loss: 6.7129e-04
# Epoch 95/100
# 69/69 [==============================] - 4s 58ms/step - loss: 7.0378e-04
# Epoch 96/100
# 69/69 [==============================] - 4s 56ms/step - loss: 6.2577e-04
# Epoch 97/100
# 69/69 [==============================] - 4s 57ms/step - loss: 5.7333e-04
# Epoch 98/100
# 69/69 [==============================] - 4s 56ms/step - loss: 5.3450e-04
# Epoch 99/100
# 69/69 [==============================] - 4s 56ms/step - loss: 6.8361e-04
# Epoch 100/100
# 69/69 [==============================] - 4s 58ms/step - loss: 6.1766e-04

# %%
full_dataset = pd.concat((training_data["Open"],test_data["Open"]), axis=0)

dates = test_data.Date
inputs = full_dataset[len(full_dataset)-len(test_data)-60:].values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)
x_test = []

for i in range (60,313):
    x_test.append(inputs[i-60:i, 0])
x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

predicted_stock_prices = regressor.predict(x_test)
predicted_stock_prices = sc.inverse_transform(predicted_stock_prices)
# Out:
# 8/8 [==============================] - 0s 12ms/step

# %%
actual_stock_prices = test_data.iloc[:,1:2].values

plt.figure(figsize=(15,10))
plt.plot(dates, actual_stock_prices, color='red', label = "Actual Stock Prices")
plt.plot(dates, predicted_stock_prices, color='blue', label = "Predicted Stock Prices")
plt.xticks([0, 50, 100, 150, 200, 252])
plt.legend()
